# %% [markdown]
# # A direkt és az inverz feladat megoldási módszerei
#
#
# Ezen notebook kiegészítséként szolgál a dolgozat 6. fejezetéhez.
#
# A fejezetben említett teljesítménymérésre szolgáló notebook elérhetősége:
# - ./performance_measure/runtime-measure.ipynb

# %% [markdown]
# ## Példa a dolgozatban használt adathalmazok elemeire

# %%
import tensorflow as tf
from tensaorflow import keras
import matplotlib.pyplot as plt

import numpy as np
# Out:
# 2022-05-03 15:02:26.247371: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-05-03 15:02:26.247418: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
# AFHQ
# az adathalmaz elérhető az alábbi linken: https://www.kaggle.com/datasets/andrewmvd/animal-faces
data_dir = r'./datas/afhq/train'
image_size = (512, 512)

dataset = keras.preprocessing.image_dataset_from_directory(
    data_dir, image_size=image_size, batch_size=32
)

class_names = ["cat", "dog", "wild"]

plt.figure(figsize=(8, 4), dpi=100)
for images, labels in dataset.take(1):
    for i in range(8):
        ax = plt.subplot(2, 4, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")
plt.show()
# Out:
# Found 14630 files belonging to 3 classes.
# 2022-05-03 15:06:55.317403: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 100663296 exceeds 10% of free system memory.

# %%
#Cifar-10

(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()

class_names = ["airplane", "automobile", "bird", "cat", "deer", "dog", "frog", "horse", "ship", "truck"]

plt.figure(figsize=(8, 4), dpi=100)

for i in range(10):
    index = np.where(y_train == i)[0][0]
    ax = plt.subplot(2, 5, i + 1)
    plt.imshow(x_train[index], interpolation="none")
    plt.title(class_names[int(y_train[index])])
    plt.axis("off")
plt.show()
