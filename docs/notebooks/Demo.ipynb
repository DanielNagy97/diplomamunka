# %%
import matplotlib.pyplot as plt

from obinv.TextToImage import TextToImage
# Out:
# 2022-05-02 12:50:32.163673: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-05-02 12:50:32.163709: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
#generator_path = './datas/weights/msggan/newMSGmodel/msgGeneratornew.h5'
generator_path = './datas/weights/msggan/afhq/msgGenerator.h5' # Generator with a collapsed mode...
classifier_path = './datas/weights/classifier/animalFacesClassifier.h5'

text_to_image = TextToImage(generator_path, classifier_path)
# Out:
# 2022-05-02 12:50:34.398017: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-05-02 12:50:34.398053: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-05-02 12:50:34.398080: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (Inspiron-5558): /proc/driver/nvidia/version does not exist
# 2022-05-02 12:50:34.398343: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
input_sentence = "Egy macskáról készült fénykép"

step_size = 0.002
steps = 21

result_noises, losses, preds, structured_data = text_to_image.generate_image_from_text(
    input_sentence, step_size=step_size, steps=steps, verbose=True
)
# Out:
# tf.Tensor([[0.1596842  0.50934416 0.3309716 ]], shape=(1, 3), dtype=float32)
# Step: 0, Loss: 1.834557056427002
# tf.Tensor([[0.07691278 0.6446437  0.27844357]], shape=(1, 3), dtype=float32)
# Step: 1, Loss: 2.5650832653045654
# tf.Tensor([[0.11230894 0.840504   0.04718709]], shape=(1, 3), dtype=float32)
# Step: 2, Loss: 2.1865017414093018
# tf.Tensor([[0.68984693 0.04147938 0.2686737 ]], shape=(1, 3), dtype=float32)
# Step: 3, Loss: 0.3712855279445648
# tf.Tensor([[1.5417209e-02 4.9575843e-04 9.8408705e-01]], shape=(1, 3), dtype=float32)
# Step: 4, Loss: 4.172270774841309
# tf.Tensor([[0.05380905 0.00181557 0.9443754 ]], shape=(1, 3), dtype=float32)
# Step: 5, Loss: 2.9223134517669678
# tf.Tensor([[0.14460735 0.04064655 0.8147461 ]], shape=(1, 3), dtype=float32)
# Step: 6, Loss: 1.9337331056594849
# tf.Tensor([[2.2669774e-02 5.3564849e-04 9.7679454e-01]], shape=(1, 3), dtype=float32)
# Step: 7, Loss: 3.7867226600646973
# ...

# %%
text_to_image.plot_convergence(result_noises, losses, preds, 5)
